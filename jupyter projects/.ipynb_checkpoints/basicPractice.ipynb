# %%
# tis is a single line comment
'''This is a multi line comment'''
name="Karthik"
name="K P"
print(name)
print(name)
# Out:
# K P
# K P

# %%
# python uses indentation to define blocks of code
age=34
if ((age>=30) | (age==18)):
  {print(" its working")}
# Out:
#  its working

# %%
# Line continuation
x="abcde" \
"hijklmnop"
print(x)
# Out:
# abcdehijklmnop

# %%
# Multiple elemtnts on a single line
x=5;y=19;z=x+y
print(z)
# Out:
# 24

# %%
age=1
if ((age>=30) | (age==18)):
 print(" its also working")
else:
 print('not working')
# Out:
# not working

# %%
str="hello there, Im karthik"
str.find("hello")
# Out:
# 0

# %%
str="hello there, Im karthik"
print(str.title())
print(str)
# Out:
# Hello There, Im Karthik
# hello there, Im karthik

# %%
age=20
adult=True if age>18 else print("minor")
print(adult)
# Out:
# True
