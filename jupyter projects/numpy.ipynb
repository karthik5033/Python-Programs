# %%
# %pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# create a 1d array
# arr1=np.array([1,2,3,4,5])
# print(arr1)
# print(type(arr1))
# print(arr1.shape)
# Out:
# [1 2 3 4 5]
# <class 'numpy.ndarray'>
# (5,)

# %%
arr2=np.array([1,2,3,4,5])
arr2.reshape(1,5) 
# Basically 1 row and 5 columns
# Out:
# array([[1, 2, 3, 4, 5]])

# %%
arr2=np.array([[1,2,3,4,5],[1,3,5,7,9],[1,2,3,4,5]])
arr2.shape
print(arr2)
# Out:
# [[1 2 3 4 5]
#  [1 3 5 7 9]
#  [1 2 3 4 5]]

# %%
np.arange(0,10,2)
np.arange(0,10,2).reshape(5,1)
# Out:
# array([[0],
#        [2],
#        [4],
#        [6],
#        [8]])
