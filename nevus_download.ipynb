# %%
import pandas as pd
import os
from tqdm import tqdm

# Load metadata
meta = pd.read_csv("HAM10000_metadata.csv")

# Optional: Add age group
def age_group(age):
    if pd.isna(age): return "unknown"
    age = int(age)
    if age < 16: return "child"
    elif age < 60: return "adult"
    else: return "elderly"

meta['age_group'] = meta['age'].apply(age_group)

# Optional: Add readable disease names
label_map = {
    'akiec': 'Actinic Keratoses',
    'bcc': 'Basal Cell Carcinoma',
    'bkl': 'Benign Keratosis',
    'df': 'Dermatofibroma',
    'mel': 'Melanoma',
    'nv': 'Nevus (Mole)',
    'vasc': 'Vascular Lesion'
}

meta['disease_name'] = meta['dx'].map(label_map)

meta.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization age_group  \
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp   elderly
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp   elderly
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp   elderly
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp   elderly
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear   elderly
#
#        disease_name
# 0  Benign Keratosis
# 1  Benign Keratosis
# 2  Benign Keratosis
# 3  Benign Keratosis
# 4  Benign Keratosis

# %%
dataset_name = "kmader/skin-cancer-mnist-ham10000"

for img_id in tqdm(nevus["image_id"]):
    # Try Part 1 folder
    os.system(
        f'kaggle datasets download -d {dataset_name} '
        f'-f HAM10000_images_part_1/{img_id}.jpg '
        f'-p "{save_folder}"'
    )
    
    # Try Part 2 folder
    os.system(
        f'kaggle datasets download -d {dataset_name} '
        f'-f HAM10000_images_part_2/{img_id}.jpg '
        f'-p "{save_folder}"'
    )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 dataset_name = "kmader/skin-cancer-mnist-ham10000"
# ----> 3 for img_id in tqdm(nevus["image_id"]):
#       4     # Try Part 1 folder
#       5     os.system(
#       6         f'kaggle datasets download -d {dataset_name} '
#       7         f'-f HAM10000_images_part_1/{img_id}.jpg '
#       8         f'-p "{save_folder}"'
#       9     )
#      11     # Try Part 2 folder
#
# NameError: name 'nevus' is not defined
